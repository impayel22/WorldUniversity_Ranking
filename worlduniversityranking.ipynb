# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
X = card.drop(["cardio"], axis=1)

# %%
#importing library we need to use in this project
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#reading the dataset from drive

ranking = pd.read_csv('gdrive/My Drive/pythondata/world_ranking.csv')

# %%
#here it will showcase the top 5 elements of the dataset 
ranking.head()
# Out:
#    world_rank                            institution  ...  year  Title
# 0           1                     Harvard University  ...  2012    NaN
# 1           2  Massachusetts Institute of Technology  ...  2012    NaN
# 2           3                    Stanford University  ...  2012    NaN
# 3           4                University of Cambridge  ...  2012    NaN
# 4           5     California Institute of Technology  ...  2012    NaN
#
# [5 rows x 15 columns]

# %%
ranking.head(20)
# Out:
#     world_rank                                      institution  ...  year  Title
# 0            1                               Harvard University  ...  2012    NaN
# 1            2            Massachusetts Institute of Technology  ...  2012    NaN
# 2            3                              Stanford University  ...  2012    NaN
# 3            4                          University of Cambridge  ...  2012    NaN
# 4            5               California Institute of Technology  ...  2012    NaN
# 5            6                             Princeton University  ...  2012    NaN
# 6            7                             University of Oxford  ...  2012    NaN
# 7            8                                  Yale University  ...  2012    NaN
# 8            9                              Columbia University  ...  2012    NaN
# 9           10               University of California, Berkeley  ...  2012    NaN
# ...

# %%
ranking.shape
# Out:
# (2200, 14)

# %%
#Checking any null exist
ranking.isnull().any()
# Out:
# world_rank              False
# institution             False
# country                 False
# national_rank           False
# quality_of_education    False
# alumni_employment       False
# quality_of_faculty      False
# publications            False
# influence               False
# citations               False
# broad_impact             True
# patents                 False
# score                   False
# year                    False
# dtype: bool

# %%
# Counting the sum of null
ranking.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
ranking['broad_impact'].value_counts()
# Out:
# Series([], Name: broad_impact, dtype: int64)

# %%
# split x as world_ranking and y ase institution
x = ranking[['world_rank']]
y = ranking['national_rank']

# %%
plt.scatter(ranking['world_rank'],ranking['national_rank'] ,marker= '+', color = 'pink')
plt.title('Universities world and national ranking')
plt.xlabel('World ranking in position')
plt.ylabel('National ranking in position')
# Out:
# Text(0, 0.5, 'National ranking in position')

# %%
sns.jointplot(x='quality_of_education',y='quality_of_faculty',kind="hex",data=ranking)

# %%
x
# Out:
#       world_rank
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ...          ...
# 2195         996
# 2196         997
# 2197         998
# 2198         999
# 2199        1000
#
# [2200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=.30,random_state = 1)

# %%
xtrain
# Out:
#       world_rank
# 625          426
# 642          443
# 39            40
# 2191         992
# 456          257
# ...          ...
# 960          761
# 905          706
# 1096         897
# 235           36
# 1061         862
#
# [1540 rows x 1 columns]

# %%
xtest
# Out:
#       world_rank
# 1276          77
# 1446         247
# 335          136
# 1458         259
# 2038         839
# ...          ...
# 1418         219
# 478          279
# 1181         982
# 1000         801
# 1132         933
#
# [660 rows x 1 columns]

# %%
ytest
# Out:
# 1276     47
# 1446      6
# 335       2
# 1458    100
# 2038     62
#        ...
# 1418     91
# 478      14
# 1181     75
# 1000     27
# 1132      1
# Name: national_rank, Length: 660, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
reg.predict(xtest)
# Out:
# array([25.96487346, 32.72311887, 28.31038217, 33.20017149, 56.25771465,
#        27.47554009, 30.45711894, 40.39571513, 54.90606557, 31.01368033,
#        53.91220595, 25.52757523, 58.92125843, 61.18725836, 37.73217135,
#        55.78066204, 56.49624096, 48.62487278, 54.94581996, 41.90638175,
#        49.06217101, 36.42027666, 51.48718848, 44.1326273 , 31.57024172,
#        58.16592512, 23.30132969, 49.26094294, 54.46876734, 28.35013655,
#        25.68659277, 23.73862792, 33.35918903, 37.29487312, 37.25511874,
#        53.03760949, 61.06799521, 45.24575007, 39.4416099 , 39.83915375,
#        34.07476796, 25.68659277, 41.11129406, 46.478136  , 48.46585524,
#        51.76546918, 43.0990133 , 59.67659174, 24.57347   , 57.88764443,
#        26.60094362, 23.97715423, 48.38634647, 52.00399548, 60.23315313,
#        42.70146945, 30.65589087, 28.82718917, 51.64620602, 61.54504783,
#        43.13876768, 42.14490806, 50.85111833, 55.54213573, 60.39217067,
# ...

# %%
plt.scatter(ranking['world_rank'],ranking['national_rank'] ,marker= '+', color = 'yellow')
plt.title('University world and national ranking')
plt.xlabel('World ranking in Position')
plt.ylabel('National ranking in Position')
plt.plot(ranking.world_rank, reg.predict(ranking[['world_rank']]))

# %%
plt.scatter(xtest, ytest, color='black')
plt.plot(xtrain, reg.predict(xtrain), color='blue')
plt.title('University world and national ranking')
plt.xlabel('World ranking in position')
plt.ylabel('National ranking in position')
plt.show()
